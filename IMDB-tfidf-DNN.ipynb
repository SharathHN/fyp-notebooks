# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
def display_metrics(y_test,y_pred):
    print(accuracy_score(y_test, y_pred))
    print(f1_score(y_test, y_pred, average="macro"))
    print(precision_score(y_test, y_pred, average="macro"))
    print(recall_score(y_test, y_pred, average="macro"))

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Drive already mounted at /content/gdrive; to attempt to forcibly remount, call drive.mount("/content/gdrive", force_remount=True).

# %%
import pandas as pd
url="/content/gdrive/MyDrive/FYP/IMDb/Tf-Idf/IMDB-tfidf.csv"
df=pd.read_csv(url)
y=pd.get_dummies(df["sentiment"])
X=df.iloc[:,2:]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Dropout
# define the model
model = Sequential()
model.add(Dense(32, input_dim=X.shape[1],activation="sigmoid"))
model.add(Dropout(0.6))
# model.add(Dense(32,activation="sigmoid"))
# model.add(Dropout(0.6))
model.add(Dense(16,activation="sigmoid"))
model.add(Dropout(0.6))
model.add(Dense(2,activation="softmax"))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100, batch_size=16, verbose=1)
model.save('/content/gdrive/MyDrive/model')
# Out:
# Epoch 1/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.7004 - accuracy: 0.5315
# Epoch 2/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.5600 - accuracy: 0.7106
# Epoch 3/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.4323 - accuracy: 0.8091
# Epoch 4/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.3787 - accuracy: 0.8419
# Epoch 5/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.3547 - accuracy: 0.8534
# Epoch 6/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.3384 - accuracy: 0.8620
# Epoch 7/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.3225 - accuracy: 0.8683
# Epoch 8/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.3112 - accuracy: 0.8749
# Epoch 9/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.3045 - accuracy: 0.8779
# Epoch 10/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2969 - accuracy: 0.8804
# Epoch 11/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2889 - accuracy: 0.8843
# Epoch 12/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2842 - accuracy: 0.8859
# Epoch 13/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2792 - accuracy: 0.8901
# Epoch 14/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2728 - accuracy: 0.8902
# Epoch 15/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2716 - accuracy: 0.8921
# Epoch 16/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2678 - accuracy: 0.8961
# Epoch 17/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2650 - accuracy: 0.8964
# Epoch 18/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2627 - accuracy: 0.8959
# Epoch 19/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2610 - accuracy: 0.8956
# Epoch 20/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2546 - accuracy: 0.9003
# Epoch 21/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2531 - accuracy: 0.9013
# Epoch 22/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2523 - accuracy: 0.9025
# Epoch 23/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2493 - accuracy: 0.9017
# Epoch 24/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2473 - accuracy: 0.9039
# Epoch 25/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2474 - accuracy: 0.9032
# Epoch 26/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2419 - accuracy: 0.9047
# Epoch 27/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2384 - accuracy: 0.9053
# Epoch 28/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2432 - accuracy: 0.9057
# Epoch 29/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2369 - accuracy: 0.9073
# Epoch 30/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2396 - accuracy: 0.9065
# Epoch 31/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2336 - accuracy: 0.9084
# Epoch 32/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2309 - accuracy: 0.9086
# Epoch 33/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2314 - accuracy: 0.9102
# Epoch 34/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2329 - accuracy: 0.9095
# Epoch 35/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.2281 - accuracy: 0.9106
# Epoch 36/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2287 - accuracy: 0.9101
# Epoch 37/100
# 2344/2344 [==============================] - 10s 4ms/step - loss: 0.2258 - accuracy: 0.9118
# Epoch 38/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2236 - accuracy: 0.9122
# Epoch 39/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2218 - accuracy: 0.9122
# Epoch 40/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2202 - accuracy: 0.9129
# Epoch 41/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2198 - accuracy: 0.9136
# Epoch 42/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2198 - accuracy: 0.9154
# Epoch 43/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2151 - accuracy: 0.9151
# Epoch 44/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2169 - accuracy: 0.9147
# Epoch 45/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2158 - accuracy: 0.9153
# Epoch 46/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2129 - accuracy: 0.9170
# Epoch 47/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2131 - accuracy: 0.9163
# Epoch 48/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2100 - accuracy: 0.9164
# Epoch 49/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2105 - accuracy: 0.9174
# Epoch 50/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2093 - accuracy: 0.9172
# Epoch 51/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2086 - accuracy: 0.9176
# Epoch 52/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2069 - accuracy: 0.9179
# Epoch 53/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2070 - accuracy: 0.9170
# Epoch 54/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2042 - accuracy: 0.9189
# Epoch 55/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2018 - accuracy: 0.9217
# Epoch 56/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2005 - accuracy: 0.9200
# Epoch 57/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2031 - accuracy: 0.9178
# Epoch 58/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1991 - accuracy: 0.9213
# Epoch 59/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.2019 - accuracy: 0.9195
# Epoch 60/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1961 - accuracy: 0.9226
# Epoch 61/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1981 - accuracy: 0.9214
# Epoch 62/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1936 - accuracy: 0.9232
# Epoch 63/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1973 - accuracy: 0.9209
# Epoch 64/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1942 - accuracy: 0.9225
# Epoch 65/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1930 - accuracy: 0.9237
# Epoch 66/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1932 - accuracy: 0.9251
# Epoch 67/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1888 - accuracy: 0.9253
# Epoch 68/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1904 - accuracy: 0.9226
# Epoch 69/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1897 - accuracy: 0.9251
# Epoch 70/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1890 - accuracy: 0.9237
# Epoch 71/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1861 - accuracy: 0.9249
# Epoch 72/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1841 - accuracy: 0.9264
# Epoch 73/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1860 - accuracy: 0.9257
# Epoch 74/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1842 - accuracy: 0.9280
# Epoch 75/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1832 - accuracy: 0.9291
# Epoch 76/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1793 - accuracy: 0.9289
# Epoch 77/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1786 - accuracy: 0.9289
# Epoch 78/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1790 - accuracy: 0.9275
# Epoch 79/100
# 2344/2344 [==============================] - 8s 4ms/step - loss: 0.1797 - accuracy: 0.9290
# Epoch 80/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1791 - accuracy: 0.9301
# Epoch 81/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1768 - accuracy: 0.9294
# Epoch 82/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1770 - accuracy: 0.9303
# Epoch 83/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1729 - accuracy: 0.9323
# Epoch 84/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1763 - accuracy: 0.9307
# Epoch 85/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1706 - accuracy: 0.9322
# Epoch 86/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1736 - accuracy: 0.9318
# Epoch 87/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1722 - accuracy: 0.9328
# Epoch 88/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1699 - accuracy: 0.9324
# Epoch 89/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1694 - accuracy: 0.9344
# Epoch 90/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1674 - accuracy: 0.9343
# Epoch 91/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1655 - accuracy: 0.9342
# Epoch 92/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1669 - accuracy: 0.9348
# Epoch 93/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1661 - accuracy: 0.9356
# Epoch 94/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1621 - accuracy: 0.9363
# Epoch 95/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1648 - accuracy: 0.9348
# Epoch 96/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1615 - accuracy: 0.9353
# Epoch 97/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1606 - accuracy: 0.9353
# Epoch 98/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1604 - accuracy: 0.9364
# Epoch 99/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1594 - accuracy: 0.9380
# Epoch 100/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 0.1564 - accuracy: 0.9378
# INFO:tensorflow:Assets written to: /content/gdrive/MyDrive/model/assets

# %%
y_pred=model.predict(X_test)
for i in range(len(y_pred)):
  if y_pred[i]>0.5:
    y_pred[i]=1
  else:
    y_pred[i]=0

display_metrics(y_test,y_pred)

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
def display_metrics(y_test,y_pred):
    print(accuracy_score(y_test, y_pred))
    print(f1_score(y_test, y_pred, average="macro"))
    print(precision_score(y_test, y_pred, average="macro"))
    print(recall_score(y_test, y_pred, average="macro"))

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
url="/content/gdrive/MyDrive/Fyp/CountVectorizer/IMDB_countVectorsFull.csv"
df=pd.read_csv(url)
y=df["sentiment"]
X=df.iloc[:,2:]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense
# define the model
model = Sequential()
model.add(Dense(128, input_dim=X.shape[1],activation="sigmoid"))
#model.add(Dense(64,activation="sigmoid"))
model.add(Dense(1,activation="sigmoid"))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=100, batch_size=16, verbose=1)
# Out:
# Epoch 1/100
# 2344/2344 [==============================] - 9s 3ms/step - loss: 0.3271 - accuracy: 0.8668
# Epoch 2/100
# 2344/2344 [==============================] - 8s 4ms/step - loss: 0.2593 - accuracy: 0.8930
# Epoch 3/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.2403 - accuracy: 0.9012
# Epoch 4/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.2243 - accuracy: 0.9093
# Epoch 5/100
# 2344/2344 [==============================] - 9s 4ms/step - loss: 0.2091 - accuracy: 0.9165
# Epoch 6/100
# 2344/2344 [==============================] - 8s 4ms/step - loss: 0.1924 - accuracy: 0.9221
# Epoch 7/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.1730 - accuracy: 0.9332
# Epoch 8/100
# 2344/2344 [==============================] - 9s 4ms/step - loss: 0.1494 - accuracy: 0.9444
# Epoch 9/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.1232 - accuracy: 0.9582
# Epoch 10/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.0954 - accuracy: 0.9703
# Epoch 11/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.0696 - accuracy: 0.9801
# Epoch 12/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.0479 - accuracy: 0.9882
# Epoch 13/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.0313 - accuracy: 0.9931
# Epoch 14/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.0197 - accuracy: 0.9965
# Epoch 15/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.0119 - accuracy: 0.9979
# Epoch 16/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.0071 - accuracy: 0.9989
# Epoch 17/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.0042 - accuracy: 0.9995
# Epoch 18/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.0025 - accuracy: 0.9998
# Epoch 19/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 0.0015 - accuracy: 0.9999
# Epoch 20/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 8.7973e-04 - accuracy: 0.9999
# Epoch 21/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.5331e-04 - accuracy: 0.9999
# Epoch 22/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 2.6909e-04 - accuracy: 0.9999
# Epoch 23/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 1.5113e-04 - accuracy: 1.0000
# Epoch 24/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 9.2074e-05 - accuracy: 1.0000
# Epoch 25/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.6038e-05 - accuracy: 1.0000
# Epoch 26/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 2.1786e-05 - accuracy: 1.0000
# Epoch 27/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 1.1748e-05 - accuracy: 1.0000
# Epoch 28/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 5.7654e-06 - accuracy: 1.0000
# Epoch 29/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.4078e-06 - accuracy: 1.0000
# Epoch 30/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 1.4788e-06 - accuracy: 1.0000
# Epoch 31/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 8.5600e-07 - accuracy: 1.0000
# Epoch 32/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 5.0004e-07 - accuracy: 1.0000
# Epoch 33/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.1019e-07 - accuracy: 1.0000
# Epoch 34/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 2.0511e-07 - accuracy: 1.0000
# Epoch 35/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 1.2299e-07 - accuracy: 1.0000
# Epoch 36/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 8.9082e-08 - accuracy: 1.0000
# Epoch 37/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 6.0901e-08 - accuracy: 1.0000
# Epoch 38/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.9775e-08 - accuracy: 1.0000
# Epoch 39/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.7688e-08 - accuracy: 1.0000
# Epoch 40/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.1036e-08 - accuracy: 1.0000
# Epoch 41/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 2.5204e-08 - accuracy: 1.0000
# Epoch 42/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 2.1957e-08 - accuracy: 1.0000
# Epoch 43/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 1.8951e-08 - accuracy: 1.0000
# Epoch 44/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 1.6583e-08 - accuracy: 1.0000
# Epoch 45/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 1.4667e-08 - accuracy: 1.0000
# Epoch 46/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 1.3391e-08 - accuracy: 1.0000
# Epoch 47/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 1.2135e-08 - accuracy: 1.0000
# Epoch 48/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 1.1235e-08 - accuracy: 1.0000
# Epoch 49/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 1.0391e-08 - accuracy: 1.0000
# Epoch 50/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 9.6376e-09 - accuracy: 1.0000
# Epoch 51/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 9.0403e-09 - accuracy: 1.0000
# Epoch 52/100
# 2344/2344 [==============================] - 7s 3ms/step - loss: 8.5257e-09 - accuracy: 1.0000
# Epoch 53/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 8.0663e-09 - accuracy: 1.0000
# Epoch 54/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 7.6685e-09 - accuracy: 1.0000
# Epoch 55/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 7.3210e-09 - accuracy: 1.0000
# Epoch 56/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 6.9813e-09 - accuracy: 1.0000
# Epoch 57/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 6.6904e-09 - accuracy: 1.0000
# Epoch 58/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 6.4453e-09 - accuracy: 1.0000
# Epoch 59/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 6.2042e-09 - accuracy: 1.0000
# Epoch 60/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 5.9759e-09 - accuracy: 1.0000
# Epoch 61/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 5.7990e-09 - accuracy: 1.0000
# Epoch 62/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 5.6064e-09 - accuracy: 1.0000
# Epoch 63/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 5.4396e-09 - accuracy: 1.0000
# Epoch 64/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 5.2754e-09 - accuracy: 1.0000
# Epoch 65/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 5.1388e-09 - accuracy: 1.0000
# Epoch 66/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.9948e-09 - accuracy: 1.0000
# Epoch 67/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.8854e-09 - accuracy: 1.0000
# Epoch 68/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.7620e-09 - accuracy: 1.0000
# Epoch 69/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.6516e-09 - accuracy: 1.0000
# Epoch 70/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.5434e-09 - accuracy: 1.0000
# Epoch 71/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.4482e-09 - accuracy: 1.0000
# Epoch 72/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.3659e-09 - accuracy: 1.0000
# Epoch 73/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.2935e-09 - accuracy: 1.0000
# Epoch 74/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.1975e-09 - accuracy: 1.0000
# Epoch 75/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.1439e-09 - accuracy: 1.0000
# Epoch 76/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 4.0662e-09 - accuracy: 1.0000
# Epoch 77/100
# 2344/2344 [==============================] - 8s 4ms/step - loss: 4.0156e-09 - accuracy: 1.0000
# Epoch 78/100
# 2344/2344 [==============================] - 9s 4ms/step - loss: 3.9407e-09 - accuracy: 1.0000
# Epoch 79/100
# 2344/2344 [==============================] - 9s 4ms/step - loss: 3.8861e-09 - accuracy: 1.0000
# Epoch 80/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.8307e-09 - accuracy: 1.0000
# Epoch 81/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.7855e-09 - accuracy: 1.0000
# Epoch 82/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.7284e-09 - accuracy: 1.0000
# Epoch 83/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.6813e-09 - accuracy: 1.0000
# Epoch 84/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.6344e-09 - accuracy: 1.0000
# Epoch 85/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.5930e-09 - accuracy: 1.0000
# Epoch 86/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.5591e-09 - accuracy: 1.0000
# Epoch 87/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.5206e-09 - accuracy: 1.0000
# Epoch 88/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.4852e-09 - accuracy: 1.0000
# Epoch 89/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.4345e-09 - accuracy: 1.0000
# Epoch 90/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.4096e-09 - accuracy: 1.0000
# Epoch 91/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.3807e-09 - accuracy: 1.0000
# Epoch 92/100
# 2344/2344 [==============================] - 8s 3ms/step - loss: 3.3551e-09 - accuracy: 1.0000
# Epoch 93/100
# 2344/2344 [==============================] - 8s 4ms/step - loss: 3.3271e-09 - accuracy: 1.0000
# Epoch 94/100
# 2344/2344 [==============================] - 8s 4ms/step - loss: 3.2949e-09 - accuracy: 1.0000
# Epoch 95/100
# 2344/2344 [==============================] - 9s 4ms/step - loss: 3.2711e-09 - accuracy: 1.0000
# Epoch 96/100
#  277/2344 [==>...........................] - ETA: 7s - loss: 3.7677e-09 - accuracy: 1.0000

# %%
y_pred=model.predict(X_test)
for i in range(len(y_pred)):
  if y_pred[i]>0.5:
    y_pred[i]=1
  else:
    y_pred[i]=0

# %%
display_metrics(y_test,y_pred)
# Out:
# 0.86136
# 0.8613566982929558
# 0.8614075668825213
# 0.861478129263104

# %%
from sklearn.metrics import accuracy_score, f1_score, precision_score, recall_score
def display_metrics(y_test,y_pred):
    print(accuracy_score(y_test, y_pred))
    print(f1_score(y_test, y_pred, average="macro"))
    print(precision_score(y_test, y_pred, average="macro"))
    print(recall_score(y_test, y_pred, average="macro"))

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
url="/content/gdrive/MyDrive/Fyp/CountVectorizer/IMDB_countVectorsFull.csv"
df=pd.read_csv(url)

# %%
y=df["sentiment"]
X=df.iloc[:,2:]
import numpy as np
X=np.array(X)
X=X.reshape(50000,3000,1)
X=X.astype('float32')

# %%
X.shape
# Out:
# (50000, 3000, 1)

# %%
#Train test split
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.25, random_state=42)

# %%
from tensorflow.keras import Sequential
from tensorflow.keras.layers import Dense,Bidirectional,LSTM,GRU
# define the model
model = Sequential()
model.add(LSTM(10,activation="sigmoid",dtype='float32'))
model.add(Dense(128,activation="sigmoid"))
#model.add(Dense(64,activation="sigmoid"))
model.add(Dense(1,activation="sigmoid"))

# %%
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
model.fit(X_train, y_train, epochs=10, batch_size=256, verbose=1)
# Out:
# Epoch 1/10
# 147/147 [==============================] - 199s 1s/step - loss: 0.6939 - accuracy: 0.5019
# Epoch 2/10
# 147/147 [==============================] - 199s 1s/step - loss: 0.6938 - accuracy: 0.4986
# Epoch 3/10
# 147/147 [==============================] - 195s 1s/step - loss: 0.6937 - accuracy: 0.4954
# Epoch 4/10
# 147/147 [==============================] - 194s 1s/step - loss: 0.6935 - accuracy: 0.4977
# Epoch 5/10
# 147/147 [==============================] - 198s 1s/step - loss: 0.6939 - accuracy: 0.4974
# Epoch 6/10
# 147/147 [==============================] - 197s 1s/step - loss: 0.6936 - accuracy: 0.5014
# Epoch 7/10
# 147/147 [==============================] - 194s 1s/step - loss: 0.6934 - accuracy: 0.5011
# Epoch 8/10
# 147/147 [==============================] - 199s 1s/step - loss: 0.6935 - accuracy: 0.4995
# Epoch 9/10
# 147/147 [==============================] - 196s 1s/step - loss: 0.6937 - accuracy: 0.5029
# Epoch 10/10
# ...

# %%
y_pred=model.predict(X_test)

# %%
model.evaluate(X_test,y_test)
# Out:
# 391/391 [==============================] - 67s 167ms/step - loss: 0.6938 - accuracy: 0.4926
# [0.6938155293464661, 0.4925599992275238]

# %%
for i in range(len(y_pred)):
  if y_pred[i]>0.5:
    y_pred[i]=1
  else:
    y_pred[i]=0
display_metrics(y_test,y_pred)
# Out:
# 0.49256
# 0.33001018384520553
# 0.24628
# 0.5
# /usr/local/lib/python3.7/dist-packages/sklearn/metrics/_classification.py:1318: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

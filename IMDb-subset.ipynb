# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
import pandas as pd
df = pd.read_csv("/content/gdrive/MyDrive/FYP/IMDb/IMDB-preprocessed.csv", names=['sentiment', 'new_text'], encoding='latin-1')
df = df[1:]
df.head()
# Out:
#   sentiment                                           new_text
# 1         1  one of the other reviewers has mentioned that ...
# 2         1  a wonderful little production br br the filmin...
# 3         1  i thought this was a wonderful way to spend ti...
# 4         0  basically there is a family where a little boy...
# 5         1  petter mattei s love in the time of money is a...

# %%
df.sentiment.value_counts()
# Out:
# 1    25000
# 0    25000
# Name: sentiment, dtype: int64

# %%
df = df.sample(n=10000)
df.sentiment.value_counts()
# Out:
# 1    5002
# 0    4998
# Name: sentiment, dtype: int64

# %%
df.to_csv("/content/gdrive/MyDrive/Fyp/IMDB-subset.csv", index=False)
